# %% [markdown]
# # Importing libraries

# %%
# suppress display of warnings
import warnings
warnings.filterwarnings("ignore")

# 'Pandas' is used for data manipulation and analysis
import pandas as pd 

# 'Numpy' is used for mathematical operations on large, multi-dimensional arrays and matrices
import numpy as np

# 'Matplotlib' is a data visualization library for 2D and 3D plots, built on numpy
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# 'Seaborn' is based on matplotlib; used for plotting statistical graphics
import seaborn as sns

# import 'is_string_dtype' to check if the type of input is string  
from pandas.api.types import is_string_dtype

# import various functions to perform classification
from sklearn.naive_bayes import GaussianNB
from sklearn.multiclass import OneVsRestClassifier
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn import tree
from sklearn.tree import export_graphviz
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.feature_selection import SelectFromModel
from sklearn.svm import SVC
# display all columns of the dataframe
pd.options.display.max_columns = None

# %%
#setting the plot size using rcParams
plt.rcParams['figure.figsize'] = [15,8]

# %%
#importing datasets for training and testing the models
df=pd.read_csv("survey.csv")

#rwading the first 5 records from the training data set
df.head()
# Out:
#              Timestamp  Age  Gender         Country state self_employed  \
# 0  2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1  2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2  2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3  2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4  2014-08-27 11:30:22   31    Male   United States    TX           NaN
#
#   family_history treatment work_interfere    no_employees remote_work  \
# 0             No       Yes          Often            6-25          No
# 1             No        No         Rarely  More than 1000          No
# 2             No        No         Rarely            6-25          No
# 3            Yes       Yes          Often          26-100          No
# 4             No        No          Never         100-500         Yes
#
#   tech_company    benefits care_options wellness_program   seek_help  \
# 0          Yes         Yes     Not sure               No         Yes
# 1           No  Don't know           No       Don't know  Don't know
# 2          Yes          No           No               No          No
# 3          Yes          No          Yes               No          No
# 4          Yes         Yes           No       Don't know  Don't know
#
#     anonymity               leave mental_health_consequence  \
# 0         Yes       Somewhat easy                        No
# 1  Don't know          Don't know                     Maybe
# 2  Don't know  Somewhat difficult                        No
# 3          No  Somewhat difficult                       Yes
# 4  Don't know          Don't know                        No
#
#   phys_health_consequence     coworkers supervisor mental_health_interview  \
# 0                      No  Some of them        Yes                      No
# 1                      No            No         No                      No
# 2                      No           Yes        Yes                     Yes
# 3                     Yes  Some of them         No                   Maybe
# 4                      No  Some of them        Yes                     Yes
#
#   phys_health_interview mental_vs_physical obs_consequence comments
# 0                 Maybe                Yes              No      NaN
# 1                    No         Don't know              No      NaN
# 2                   Yes                 No              No      NaN
# 3                 Maybe                 No             Yes      NaN
# 4                   Yes         Don't know              No      NaN

# %%
print(df.columns)
# Out:
# Index(['Timestamp', 'Age', 'Gender', 'Country', 'state', 'self_employed',
#        'family_history', 'treatment', 'work_interfere', 'no_employees',
#        'remote_work', 'tech_company', 'benefits', 'care_options',
#        'wellness_program', 'seek_help', 'anonymity', 'leave',
#        'mental_health_consequence', 'phys_health_consequence', 'coworkers',
#        'supervisor', 'mental_health_interview', 'phys_health_interview',
#        'mental_vs_physical', 'obs_consequence', 'comments'],
#       dtype='object')

# %% [markdown]
# # Understanding the data set

# %%
#checking the number of rows and columns in the training data set
df.shape
# Out:
# (1259, 27)

# %%
# 'dtypes' gives the data type for each column
df.dtypes
# Out:
# Timestamp                    object
# Age                           int64
# Gender                       object
# Country                      object
# state                        object
# self_employed                object
# family_history               object
# treatment                    object
# work_interfere               object
# no_employees                 object
# remote_work                  object
# tech_company                 object
# benefits                     object
# care_options                 object
# wellness_program             object
# seek_help                    object
# anonymity                    object
# leave                        object
# mental_health_consequence    object
# phys_health_consequence      object
# coworkers                    object
# supervisor                   object
# mental_health_interview      object
# phys_health_interview        object
# mental_vs_physical           object
# obs_consequence              object
# comments                     object
# dtype: object

# %% [markdown]
# From the above output we can see that all the features are of object data type, except serial number and age.
# But timestamp is wrongly attributed as object which should be datetime datatype.We will convert the datatype of timestamp.

# %%
#Splitting the timestamp feature as it includes both date and time
df[['Date','Time']]=df['Timestamp'].str.split(" ",n=1,expand=True)

# %%
df.head()
# Out:
#              Timestamp  Age  Gender         Country state self_employed  \
# 0  2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1  2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2  2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3  2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4  2014-08-27 11:30:22   31    Male   United States    TX           NaN
#
#   family_history treatment work_interfere    no_employees remote_work  \
# 0             No       Yes          Often            6-25          No
# 1             No        No         Rarely  More than 1000          No
# 2             No        No         Rarely            6-25          No
# 3            Yes       Yes          Often          26-100          No
# 4             No        No          Never         100-500         Yes
#
#   tech_company    benefits care_options wellness_program   seek_help  \
# 0          Yes         Yes     Not sure               No         Yes
# 1           No  Don't know           No       Don't know  Don't know
# 2          Yes          No           No               No          No
# 3          Yes          No          Yes               No          No
# 4          Yes         Yes           No       Don't know  Don't know
#
#     anonymity               leave mental_health_consequence  \
# 0         Yes       Somewhat easy                        No
# 1  Don't know          Don't know                     Maybe
# 2  Don't know  Somewhat difficult                        No
# 3          No  Somewhat difficult                       Yes
# 4  Don't know          Don't know                        No
#
#   phys_health_consequence     coworkers supervisor mental_health_interview  \
# 0                      No  Some of them        Yes                      No
# 1                      No            No         No                      No
# 2                      No           Yes        Yes                     Yes
# 3                     Yes  Some of them         No                   Maybe
# 4                      No  Some of them        Yes                     Yes
#
#   phys_health_interview mental_vs_physical obs_consequence comments  \
# 0                 Maybe                Yes              No      NaN
# 1                    No         Don't know              No      NaN
# 2                   Yes                 No              No      NaN
# 3                 Maybe                 No             Yes      NaN
# 4                   Yes         Don't know              No      NaN
#
#          Date      Time
# 0  2014-08-27  11:29:31
# 1  2014-08-27  11:29:37
# 2  2014-08-27  11:29:44
# 3  2014-08-27  11:29:46
# 4  2014-08-27  11:30:22

# %%
#dropping the timestamp column as we have already created two columns which have date and time
#axis=1 deletes the entire column
df.drop('Timestamp',axis=1,inplace=True)

# %%
#converting the datatype of date and time columns
df['Time']=pd.to_datetime(df['Time'],format='%H:%M:%S')
df['Date']=pd.to_datetime(df['Date'])

# %%
#finally checking the columns and their datatypes after alteration
df.dtypes
# Out:
# Age                                   int64
# Gender                               object
# Country                              object
# state                                object
# self_employed                        object
# family_history                       object
# treatment                            object
# work_interfere                       object
# no_employees                         object
# remote_work                          object
# tech_company                         object
# benefits                             object
# care_options                         object
# wellness_program                     object
# seek_help                            object
# anonymity                            object
# leave                                object
# mental_health_consequence            object
# phys_health_consequence              object
# coworkers                            object
# supervisor                           object
# mental_health_interview              object
# phys_health_interview                object
# mental_vs_physical                   object
# obs_consequence                      object
# comments                             object
# Date                         datetime64[ns]
# Time                         datetime64[ns]
# dtype: object

# %% [markdown]
# Now all the features are having correct datatypes

# %%
# the describe() returns the statistical summary of the numeric variables
df.describe()
# Out:
#                 Age
# count  1.259000e+03
# mean   7.942815e+07
# std    2.818299e+09
# min   -1.726000e+03
# 25%    2.700000e+01
# 50%    3.100000e+01
# 75%    3.600000e+01
# max    1.000000e+11

# %%
df.Age.min()
# Out:
# -1726

# %% [markdown]
# The summary contains information about the count,mean,highest,lowest values of the columns and their 1st,2nd and 3rd quartiles values as well.From the above output we can see that both the columns doesnot have any missing values as the count of both the variables is equal to the number of rows.But in age we see some discrepency.The maximum age is 99999999999 and the minimum is -1726.We need to handle these data.

# %%
#it gives the statistical summary of all the categorical variables
df.describe(include=object)
# Out:
#        Gender        Country state self_employed family_history treatment  \
# count    1259           1259   744          1241           1259      1259
# unique     49             48    45             2              2         2
# top      Male  United States    CA            No             No       Yes
# freq      615            751   138          1095            767       637
#
#        work_interfere no_employees remote_work tech_company benefits  \
# count             995         1259        1259         1259     1259
# unique              4            6           2            2        3
# top         Sometimes         6-25          No          Yes      Yes
# freq              465          290         883         1031      477
#
#        care_options wellness_program seek_help   anonymity       leave  \
# count          1259             1259      1259        1259        1259
# unique            3                3         3           3           5
# top              No               No        No  Don't know  Don't know
# freq            501              842       646         819         563
#
#        mental_health_consequence phys_health_consequence     coworkers  \
# count                       1259                    1259          1259
# unique                         3                       3             3
# top                           No                      No  Some of them
# freq                         490                     925           774
#
#        supervisor mental_health_interview phys_health_interview  \
# count        1259                    1259                  1259
# unique          3                       3                     3
# top           Yes                      No                 Maybe
# freq          516                    1008                   557
#
#        mental_vs_physical obs_consequence                         comments
# count                1259            1259                              164
# unique                  3               2                              160
# top            Don't know              No  * Small family business - YMMV.
# freq                  576            1075                                5

# %% [markdown]
# From the above output we can see that the state,self-employed,work_interfere and the comments columns have missing data as the count is less than 1259.We will handle these columns.
# We see that in gender column there are 49 unique values.We need to see this column for any redundancy or error.
# The country column has 48 unique values and the data has been maximum taken from United States and the frequency is 751 out of 1259.

# %% [markdown]
# # DATA PREPARATION

# %%
#finding the unique values in the column gender
df['Gender'].unique()
# Out:
# array(['Female', 'M', 'Male', 'male', 'female', 'm', 'Male-ish', 'maile',
#        'Trans-female', 'Cis Female', 'F', 'something kinda male?',
#        'Cis Male', 'Woman', 'f', 'Mal', 'Male (CIS)', 'queer/she/they',
#        'non-binary', 'Femake', 'woman', 'Make', 'Nah', 'All', 'Enby',
#        'fluid', 'Genderqueer', 'Female ', 'Androgyne', 'Agender',
#        'cis-female/femme', 'Guy (-ish) ^_^', 'male leaning androgynous',
#        'Male ', 'Man', 'Trans woman', 'msle', 'Neuter', 'Female (trans)',
#        'queer', 'Female (cis)', 'Mail', 'cis male', 'A little about you',
#        'Malr', 'p', 'femail', 'Cis Man',
#        'ostensibly male, unsure what that really means'], dtype=object)

# %% [markdown]
# We see that there are lots of misspelled words and synonymns have been used.This is the reason there are 49
# unique values.We will convert them into 3 parts male(M),female(F) and transgender(T).

# %%
error={'Female':'F',
      'Male':'M',
      'male':'M',
      'female':'F',
      'm':'M',
      'Male-ish':'M',
      'maile':'M',
      'Trans-female':'T',
      'Cis Female':'F',
      'something kinda male?':'M',
      'Cis Male':'M',
      'Woman':'F',
      'f':'F',
      'Mal':'M',
       'Male (CIS)':'M',
      'queer/she/they':'F',
      'non-binary':'T',
      'Enby':'T',
      'Femake':'F',
      'woman':'F',
      'Make':'M',
      'fluid':'T',
      'Malr':'M',
      'cis male':'M',
      'Female (cis)':'F',
      'Guy (-ish) ^_^':'M',
      'queer':'T',
      'Female (trans)':'T',
      'male leaning androgynous':'T',
       'Neuter':'T',
       'cis-female/femme':'F',
       'msle':'M',
       'Agender':'T',
       'Genderqueer':'T',
       'Female':'F',
       'Androgyne':'T',
       'Nah':'T', 
       'All':'T',
      'Female ':'F',
       'Male ':'M', 
       'Man':'M', 
       'Trans woman':'T', 
       'Mail':'M',
       'A little about you':'T'}
df['Gender']=df['Gender'].map(error).fillna(df['Gender'])       # lambda

# %%
df['Gender'].unique()
# Out:
# array(['F', 'M', 'T', 'p', 'femail', 'Cis Man',
#        'ostensibly male, unsure what that really means'], dtype=object)

# %%
df.Gender.replace({'p':'T','femail':'F','Cis Man':'M','ostensibly male, unsure what that really means':'T'},inplace=True)

# %%
# Finding the unique values of the Gender after replacing
df.Gender.unique()
# Out:
# array(['M', 'F', 'T'], dtype=object)

# %%
df.Gender.value_counts()
# Out:
# M    993
# F    248
# T     18
# Name: Gender, dtype: int64

# %% [markdown]
# After applying the map function to the column gender and mapping the misspelled words and synonymns into 'M','F' and 'T' we see that there are only 3 unique values.

# %%
#plotting the countplot for the gender column
plt.figure(figsize=(10,4))
sns.countplot(df['Gender'],palette='rainbow')
plt.title("Countplot of the gender column")
plt.savefig('count of gender.jpg')

plt.show()

# %%
#Checking the number of male,female and transgender in the gender column
df['Gender'].value_counts()
# Out:
# M    993
# F    248
# T     18
# Name: Gender, dtype: int64

# %% [markdown]
# From the plot and the function .valuecounts() it can be clearly seen that the number of males in the data set are 993,females are 248 and transgender are 18.

# %%
#finding the unique values of age column
df['Age'].unique()
# Out:
# array([         37,          44,          32,          31,          33,
#                 35,          39,          42,          23,          29,
#                 36,          27,          46,          41,          34,
#                 30,          40,          38,          50,          24,
#                 18,          28,          26,          22,          19,
#                 25,          45,          21,         -29,          43,
#                 56,          60,          54,         329,          55,
#        99999999999,          48,          20,          57,          58,
#                 47,          62,          51,          65,          49,
#              -1726,           5,          53,          61,           8,
#                 11,          -1,          72], dtype=int64)

# %%
#removing the redundant values from the age column
df=df[df['Age']!=99999999999]
df=df[df['Age']!=-29]
df=df[df['Age']!=329]
df=df[df['Age']!=-1726]
df=df[df['Age']!=5]
df=df[df['Age']!=8]

# %%
df.shape
# Out:
# (1253, 28)

# %%
plt.figure(figsize=(15,6))
sns.countplot(df.Age)
plt.title('Count Plot of Age')
plt.savefig('countplot of Age')
plt.show()

# %% [markdown]
# # Label encoding of the treatment column

# %%
# replace 'no' with zero
df['treatment'] = df['treatment'].replace('No', 0)
# replace 'yes' with one
df['treatment'] = df['treatment'].replace('Yes', 1)

#displaying the first 5 records to check the treatment column after label enconding
df.head()
# Out:
#    Age Gender         Country state self_employed family_history  treatment  \
# 0   37      F   United States    IL           NaN             No          1
# 1   44      M   United States    IN           NaN             No          0
# 2   32      M          Canada   NaN           NaN             No          0
# 3   31      M  United Kingdom   NaN           NaN            Yes          1
# 4   31      M   United States    TX           NaN             No          0
#
#   work_interfere    no_employees remote_work tech_company    benefits  \
# 0          Often            6-25          No          Yes         Yes
# 1         Rarely  More than 1000          No           No  Don't know
# 2         Rarely            6-25          No          Yes          No
# 3          Often          26-100          No          Yes          No
# 4          Never         100-500         Yes          Yes         Yes
#
#   care_options wellness_program   seek_help   anonymity               leave  \
# 0     Not sure               No         Yes         Yes       Somewhat easy
# 1           No       Don't know  Don't know  Don't know          Don't know
# 2           No               No          No  Don't know  Somewhat difficult
# 3          Yes               No          No          No  Somewhat difficult
# 4           No       Don't know  Don't know  Don't know          Don't know
#
#   mental_health_consequence phys_health_consequence     coworkers supervisor  \
# 0                        No                      No  Some of them        Yes
# 1                     Maybe                      No            No         No
# 2                        No                      No           Yes        Yes
# 3                       Yes                     Yes  Some of them         No
# 4                        No                      No  Some of them        Yes
#
#   mental_health_interview phys_health_interview mental_vs_physical  \
# 0                      No                 Maybe                Yes
# 1                      No                    No         Don't know
# 2                     Yes                   Yes                 No
# 3                   Maybe                 Maybe                 No
# 4                     Yes                   Yes         Don't know
#
#   obs_consequence comments       Date                Time
# 0              No      NaN 2014-08-27 1900-01-01 11:29:31
# 1              No      NaN 2014-08-27 1900-01-01 11:29:37
# 2              No      NaN 2014-08-27 1900-01-01 11:29:44
# 3             Yes      NaN 2014-08-27 1900-01-01 11:29:46
# 4              No      NaN 2014-08-27 1900-01-01 11:30:22

# %%
#plotting the countplot for treatment column
sns.countplot(df['treatment'])
plt.title("Plot for treatment column")

#checking the count of each class
df['treatment'].value_counts()
# Out:
# 1    633
# 0    620
# Name: treatment, dtype: int64

# %% [markdown]
# From the above output we see that the data is mostly balanced

# %% [markdown]
# # Exploratory Data Analysis

# %%
cat_var=df.select_dtypes('object')
cat_var
# Out:
#      Gender         Country state self_employed family_history work_interfere  \
# 0         F   United States    IL           NaN             No          Often
# 1         M   United States    IN           NaN             No         Rarely
# 2         M          Canada   NaN           NaN             No         Rarely
# 3         M  United Kingdom   NaN           NaN            Yes          Often
# 4         M   United States    TX           NaN             No          Never
# ...     ...             ...   ...           ...            ...            ...
# 1254      M  United Kingdom   NaN            No             No            NaN
# 1255      M   United States    IL            No            Yes          Often
# 1256      M   United States    CA            No            Yes      Sometimes
# 1257      F   United States    NC            No             No            NaN
# 1258      M   United States    IL            No            Yes      Sometimes
#
#         no_employees remote_work tech_company    benefits care_options  \
# 0               6-25          No          Yes         Yes     Not sure
# 1     More than 1000          No           No  Don't know           No
# 2               6-25          No          Yes          No           No
# 3             26-100          No          Yes          No          Yes
# 4            100-500         Yes          Yes         Yes           No
# ...              ...         ...          ...         ...          ...
# 1254          26-100          No          Yes          No           No
# 1255          26-100         Yes          Yes         Yes          Yes
# 1256  More than 1000          No          Yes         Yes          Yes
# 1257         100-500         Yes          Yes          No          Yes
# 1258          26-100          No           No         Yes          Yes
#
#      wellness_program   seek_help   anonymity               leave  \
# 0                  No         Yes         Yes       Somewhat easy
# 1          Don't know  Don't know  Don't know          Don't know
# 2                  No          No  Don't know  Somewhat difficult
# 3                  No          No          No  Somewhat difficult
# 4          Don't know  Don't know  Don't know          Don't know
# ...               ...         ...         ...                 ...
# 1254               No          No  Don't know       Somewhat easy
# 1255               No          No         Yes  Somewhat difficult
# 1256               No          No  Don't know  Somewhat difficult
# 1257               No          No  Don't know          Don't know
# 1258               No          No         Yes          Don't know
#
#      mental_health_consequence phys_health_consequence     coworkers  \
# 0                           No                      No  Some of them
# 1                        Maybe                      No            No
# 2                           No                      No           Yes
# 3                          Yes                     Yes  Some of them
# 4                           No                      No  Some of them
# ...                        ...                     ...           ...
# 1254                        No                      No  Some of them
# 1255                        No                      No  Some of them
# 1256                       Yes                     Yes            No
# 1257                       Yes                      No            No
# 1258                     Maybe                      No  Some of them
#
#         supervisor mental_health_interview phys_health_interview  \
# 0              Yes                      No                 Maybe
# 1               No                      No                    No
# 2              Yes                     Yes                   Yes
# 3               No                   Maybe                 Maybe
# 4              Yes                     Yes                   Yes
# ...            ...                     ...                   ...
# 1254  Some of them                      No                    No
# 1255           Yes                      No                    No
# 1256            No                      No                    No
# 1257            No                      No                    No
# 1258            No                      No                    No
#
#      mental_vs_physical obs_consequence comments
# 0                   Yes              No      NaN
# 1            Don't know              No      NaN
# 2                    No              No      NaN
# 3                    No             Yes      NaN
# 4            Don't know              No      NaN
# ...                 ...             ...      ...
# 1254         Don't know              No      NaN
# 1255                Yes              No      NaN
# 1256                 No              No      NaN
# 1257                 No              No      NaN
# 1258         Don't know              No      NaN
#
# [1253 rows x 24 columns]

# %%
cat_var=df.select_dtypes(include='object')
for i in cat_var.columns:
    print(i)
    sns.countplot(df[i])
    plt.show()
# Out:
# Gender
# self_employed
# family_history
# work_interfere
# no_employees
# remote_work
# tech_company
# benefits
# care_options
# wellness_program
# seek_help
# anonymity
# leave
# mental_health_consequence
# phys_health_consequence
# coworkers
# supervisor
# mental_health_interview
# phys_health_interview
# mental_vs_physical
# obs_consequence

# %%
# create a list of all categorical variables
# initiate an empty list to store the categorical variables
categorical=[]
z=['Country','state']
# use for loop to check the data type of each variable
for column in df:
    
    # use 'if' statement with condition to check the categorical type 
    if is_string_dtype(df[column]):
        if column!=z:
        
        # append the variables with 'categoric' data type in the list 'categorical'
             categorical.append(column)


# plot the count plot for each categorical variable 
fig, ax = plt.subplots(nrows=5,ncols = 4, figsize=(25, 30))

# use for loop to plot the count plot for each variable
for variable, subplot in zip(categorical, ax.flatten()):
    
    # use countplot() to plot the graph
    sns.countplot(df[variable], ax = subplot)

# display the plot
plt.show()

# %% [markdown]
# From the plots we can see that mainly maximum variables have 3 levels except for family_history,self_employed,country,state,remote_work,work_interfere and number of employees.
#
# Deductions:
#
# 1)Number of male employees are greater than the female and transgender employees in the dataset.
#
# 2)Few number of employees in the data set are self-employed.
#
# 3)Maximum employees doesnot have any family history of mental illness.
#
# 4)Maximum employees feel that their mental condition sometimes interfere with their work.
#
# 5)Maximum employees whose data has been provided does not work from remote 50% of the time.
#
# 6)Maximum employees who have mental condition works in tech company.
#
# 7)Employees who doesnot know about mental health care that their employer provides or whose employer has not discussed mental
# health as part of an employee wellness program have mental health issue.
#
# 8)Many employees are willing to share their mental health issue with their supervisor.
#
# 9)Few employees are willing to share their mental health issue with their coworkers.

# %%
df.Gender.value_counts()
# Out:
# M    976
# F    243
# T     16
# Name: Gender, dtype: int64

# %%
plt.figure(figsize=(12,6))
plt.pie(df.Gender.value_counts(),labels=['Male','Female','Transgender'],autopct='%.2f' )
plt.legend()
plt.title('Pie Chart of Gender')
plt.show()

# %%
# plotting the counterplot for the country column 
#to see 
plt.figure(figsize=(30,8))
sns.countplot(df['Country'][:180])
plt.title("Countplot to see data has been taken from which countries",fontsize=20)
plt.show()

# %% [markdown]
# From the plot we can see that the maximum data has been taken from United States followed by United Kingdom

# %%
plt.figure(figsize=(25,8))
sns.countplot(df['state'])
plt.title("Countplot for states from which data have been collected")
plt.show()

# %% [markdown]
# From the plot we can see that maximum data has been collected from California followed by Washington

# %%
df['treatment'].value_counts().iloc[1:2]
# Out:
# 0    611
# Name: treatment, dtype: int64

# %%
#Checking employees who require treatment are from which gender
plt.figure(figsize=(10,5))
sns.countplot(df.treatment,hue=df.Gender)
plt.title('Treatment based on Gender')
plt.show()

# %%
#Checking employees who require treatment are from which gender
sns.countplot(df.treatment,hue=df.Gender,order=df['treatment'].value_counts().iloc[1:2].index)
plt.show()

# %% [markdown]
# It can be clearly seen that males requires more treatment

# %%
#plotting countplot to see how many self-employed people requires treatment
sns.countplot(df.treatment,hue=df['self_employed'],order=df['treatment'].value_counts().iloc[1:2].index)
# Out:
# <AxesSubplot:xlabel='treatment', ylabel='count'>

# %% [markdown]
# We can see that the self-employed people requires less treatment.

# %%
df.no_employees.value_counts()
# Out:
# 6-25              289
# 26-100            288
# More than 1000    281
# 100-500           175
# 1-5               160
# 500-1000           60
# Name: no_employees, dtype: int64

# %%
#checking does number of employees in an organisation affects the treatment rate
sns.countplot(df.treatment,hue=df['no_employees'],order=df['treatment'].value_counts().iloc[1:2].index)
# Out:
# <AxesSubplot:xlabel='treatment', ylabel='count'>

# %% [markdown]
# We can see from the plot that organisation have 26-100 employees and those having more than 1000 employees requires more treatment.So we can not conclude much from the organisational strength of employees.

# %%
#plot to see does how easy it to take medical leave and its affect on treatment requirement
sns.countplot(df['treatment'],hue=df['leave'],order=df['treatment'].value_counts().iloc[1:2].index)
plt.show()

# %% [markdown]
# We can see that the employees who don't know whether they will get leave for medical health condition requires treatment the maximum.

# %%
plt.figure(figsize=(10,6))
sns.countplot(df.treatment,hue=df['family_history'])
plt.show()

# %% [markdown]
# Employees with family history of mental illness needs treatment more than those who doesnot have any family history of mental illness.

# %%
sns.countplot(df['treatment'],hue=df['wellness_program'],order=df['treatment'].value_counts().iloc[1:2].index)
plt.show()

# %% [markdown]
# The employer who never discussed mental health as part of an employee wellness program are more prone to treatment requirement.

# %%
sns.countplot(df['treatment'],hue=df['tech_company'],order=df['treatment'].value_counts().iloc[1:2].index)
plt.show()

# %% [markdown]
# From the plot we can see that the tech company employees need more treatment than oganization employees.

# %%
#plotting the bar plot for age to see if there is any outlier
plt.figure(figsize=(10,6))
sns.boxplot(x=df.treatment,y=df['Age'])
plt.title('Box plot of treatment vs Age')
plt.show()

# %% [markdown]
# We see that age of people who requires treatment are in the range of 20-50years approximately.

# %% [markdown]
# From the line plot we can see that in 3 days all the data have been collected.Maximum data has been collected on 28-08-2014.

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'self_employed', 'family_history', 'treatment',
#        'work_interfere', 'no_employees', 'remote_work', 'tech_company',
#        'benefits', 'care_options', 'wellness_program', 'seek_help',
#        'anonymity', 'leave', 'mental_health_consequence',
#        'phys_health_consequence', 'coworkers', 'supervisor',
#        'mental_health_interview', 'phys_health_interview',
#        'mental_vs_physical', 'obs_consequence', 'Date', 'Time'],
#       dtype='object')

# %% [markdown]
# # Finding the missing values

# %%
# sort the variables on the basis of total null values in the variable
# 'isnull().sum()' returns the number of missing values in each variable
Total = df.isnull().sum().sort_values(ascending = False)          

# calculate the percentage of missing values
Percent = ((Total*100)/df.isnull().count()).sort_values(ascending = False)   

# concat the 'Total' and 'Percent' columns using 'concat' function
missing_data = pd.concat([Total, Percent], axis = 1, keys = ['Total', 'Percentage of Missing Values'])    
missing_data
# Out:
#                            Total  Percentage of Missing Values
# comments                    1091                     87.071030
# state                        513                     40.941740
# work_interfere               262                     20.909816
# self_employed                 18                      1.436552
# Age                            0                      0.000000
# leave                          0                      0.000000
# Date                           0                      0.000000
# obs_consequence                0                      0.000000
# mental_vs_physical             0                      0.000000
# phys_health_interview          0                      0.000000
# mental_health_interview        0                      0.000000
# supervisor                     0                      0.000000
# coworkers                      0                      0.000000
# phys_health_consequence        0                      0.000000
# mental_health_consequence      0                      0.000000
# seek_help                      0                      0.000000
# anonymity                      0                      0.000000
# Gender                         0                      0.000000
# wellness_program               0                      0.000000
# care_options                   0                      0.000000
# benefits                       0                      0.000000
# tech_company                   0                      0.000000
# remote_work                    0                      0.000000
# no_employees                   0                      0.000000
# treatment                      0                      0.000000
# family_history                 0                      0.000000
# Country                        0                      0.000000
# Time                           0                      0.000000

# %%
# plot heatmap to check null values
# 'cbar = False' does not show the color axis 
sns.heatmap(df.isnull(), cbar=False)

# display the plot
plt.show()

# %% [markdown]
# # Handling the missing values

# %%
df.drop('comments',axis=1,inplace=True)
df['work_interfere']=df['work_interfere'].fillna('Not mentioned')
df.drop(['state','Country'],axis=1,inplace=True)
df.dropna(axis=0, inplace=True)

# %%
#Checking if all the null values have been handled or not
sns.heatmap(df.isnull(),cbar=False,color='black')
plt.show()

# %% [markdown]
# # Preparing the data for building model

# %%
#Creating two dataframes df_features and df_target,df_features contains all the important features which we will dummy encode
#df_target which contains the target variable
df_features=df.drop(['treatment', 'Age','Date', 'Time'],axis=1)
df_target=df['treatment']

# %%
df_features.columns
# Out:
# Index(['Gender', 'self_employed', 'family_history', 'work_interfere',
#        'no_employees', 'remote_work', 'tech_company', 'benefits',
#        'care_options', 'wellness_program', 'seek_help', 'anonymity', 'leave',
#        'mental_health_consequence', 'phys_health_consequence', 'coworkers',
#        'supervisor', 'mental_health_interview', 'phys_health_interview',
#        'mental_vs_physical', 'obs_consequence'],
#       dtype='object')

# %%
#dummy encoding the feature(categorical) variables
df_dummy=pd.get_dummies(df_features,drop_first=True)

# %%
#storing the features in X and the target in y variable
X=df_dummy
y=pd.DataFrame(df_target)

# %% [markdown]
# # Creating generalised functions

# %%
# create a generalized function to calculate the metrics values for test set
def get_test_report(model):
    
    # return the performace measures on test set
    return(classification_report(y_test, y_pred))

# %%
# create a generalized function to calculate the metrics values for test set
def kappa_score(model):
    
    # return the kappa score on test set
    return(cohen_kappa_score(y_test, y_pred))

# %%
# define a to plot a confusion matrix for the model
def plot_confusion_matrix(model):
    
    # create a confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    conf_matrix = pd.DataFrame(data = cm,columns = ['Predicted:0','Predicted:1'], index = ['Actual:0','Actual:1'])

    # plot a heatmap to visualize the confusion matrix
    sns.heatmap(conf_matrix, annot = True, fmt = 'd', cmap = ListedColormap(['lightskyblue']), cbar = False, 
                linewidths = 0.1, annot_kws = {'size':25})

    # set the font size of x-axis ticks using 'fontsize'
    plt.xticks(fontsize = 20)

    # set the font size of y-axis ticks using 'fontsize'
    plt.yticks(fontsize = 20)

    # display the plot
    plt.show()

# %%
# define a function to plot the ROC curve and print the ROC-AUC score
def plot_roc(model):
    
    # the roc_curve() returns the values for false positive rate, true positive rate and threshold
    fpr, tpr, thresholds = roc_curve(y_test, y_pred)

    # plot the ROC curve
    plt.plot(fpr, tpr)

    # set limits for x and y axes
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.0])

    # plot the straight line showing worst prediction for the model
    plt.plot([0, 1], [0, 1],'r--')

    # add plot and axes labels
    # set text size using 'fontsize'
    plt.title('ROC Curve', fontsize = 15)
    plt.xlabel('False positive rate (1-Specificity)', fontsize = 15)
    plt.ylabel('True positive rate (Sensitivity)', fontsize = 15)

    # add the AUC score to the plot
    plt.text(x = 0.02, y = 0.9, s = ('AUC Score:',round(roc_auc_score(y_test, y_pred),4)))

    # plot the grid
    plt.grid(True)

# %%
# create an empty dataframe to store the scores for various classification algorithms
score_card = pd.DataFrame(columns=['Model', 'AUC Score', 'Precision Score', 'Recall Score', 'Accuracy Score',
                                   'Kappa Score', 'f1-score'])

def update_score_card(model_name):
    
    # assign 'score_card' as global variable
    global score_card

    # append the results to the dataframe 'score_card'
    # 'ignore_index = True' do not consider the index labels
    score_card = score_card.append({'Model': model_name,
                                    'AUC Score' : roc_auc_score(y_test, y_pred),
                                    'Precision Score': metrics.precision_score(y_test, y_pred),
                                    'Recall Score': metrics.recall_score(y_test, y_pred),
                                    'Accuracy Score': metrics.accuracy_score(y_test, y_pred),
                                    'Kappa Score': cohen_kappa_score(y_test, y_pred),
                                    'f1-score': metrics.f1_score(y_test, y_pred)}, 
                                    ignore_index = True)
    return(score_card)

# %%
# split data into train subset and test subset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30, random_state = 10)

# check the dimensions of the train & test subset using 'shape'
# print dimension of train set
print("X_train",X_train.shape)
print("y_train",y_train.shape)

# print dimension of test set
print("X_test",X_test.shape)
print("y_test",y_test.shape)
# Out:
# X_train (864, 44)
# y_train (864, 1)
# X_test (371, 44)
# y_test (371, 1)

# %% [markdown]
# # Model 1(Support vector machine)

# %%
# build the model
svclassifier = SVC(kernel = 'linear')

# fit the model
svc_model=svclassifier.fit(X_train, y_train)

# %%
# predict the values
y_pred = svclassifier.predict(X_test)

# %%
# call the function to plot the confusion matrix
plt.figure(figsize=(10,5))
plot_confusion_matrix(svc_model)

# %%
# compute the performance measures on test data
test_report = get_test_report(svc_model)

# print the performace measures
print(test_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.70      0.81       178
#            1       0.78      0.98      0.87       193
#
#     accuracy                           0.84       371
#    macro avg       0.87      0.84      0.84       371
# weighted avg       0.87      0.84      0.84       371

# %%
# compute kappa score on test set
kappa_value = kappa_score(svc_model)

# print the kappa value
print(kappa_value)
# Out:
# 0.6833632537743901

# %%
plt.figure(figsize=(10,5))

plot_roc(svc_model)

# %%
update_score_card(model_name='SVM')
# Out:
#   Model  AUC Score  Precision Score  Recall Score  Accuracy Score  \
# 0   SVM   0.837952         0.777778      0.979275        0.843666
#
#    Kappa Score  f1-score
# 0     0.683363  0.866972

# %% [markdown]
# # Model 2(Support vector machine using kernel(rbf))

# %%
# build the model
svclassifier = SVC(kernel='rbf')
# fit the model
svm_rbf=svclassifier.fit(X_train, y_train)

# %%
# predict the values
y_pred= svclassifier.predict(X_test)

# %%
plot_confusion_matrix(svm_rbf)

# %%
test_report=get_test_report(svm_rbf)
print(test_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.70      0.80       178
#            1       0.78      0.95      0.85       193
#
#     accuracy                           0.83       371
#    macro avg       0.85      0.83      0.83       371
# weighted avg       0.85      0.83      0.83       371

# %%
# compute kappa score on test set
kappa_value = kappa_score(svm_rbf)

# print the kappa value
print(kappa_value)
# Out:
# 0.6565975640215682

# %%
plot_roc(svm_rbf)

# %%
update_score_card(model_name='SVM with rbf')
# Out:
#           Model  AUC Score  Precision Score  Recall Score  Accuracy Score  \
# 0           SVM   0.837952         0.777778      0.979275        0.843666
# 1  SVM with rbf   0.825217         0.775424      0.948187        0.830189
#
#    Kappa Score  f1-score
# 0     0.683363  0.866972
# 1     0.656598  0.853147

# %% [markdown]
# # Model 3 (Support vector machine using kernel(sigmoid))

# %%
# build the model
svclassifier = SVC(kernel='sigmoid')
# fit the model
svm_sigmoid=svclassifier.fit(X_train, y_train)

# %%
# predict the values
y_pred  = svclassifier.predict(X_test)

# %%
plot_confusion_matrix(svm_sigmoid)

# %%
test_report=get_test_report(svm_sigmoid)
print(test_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.71      0.75       178
#            1       0.76      0.82      0.79       193
#
#     accuracy                           0.77       371
#    macro avg       0.77      0.77      0.77       371
# weighted avg       0.77      0.77      0.77       371

# %%
# compute kappa score on test set
kappa_value = kappa_score(svm_sigmoid)

# print the kappa value
print(kappa_value)
# Out:
# 0.5393189487677676

# %%
plot_roc(svm_sigmoid)

# %%
update_score_card(model_name='SVM using sigmoid')
# Out:
#                Model  AUC Score  Precision Score  Recall Score  \
# 0                SVM   0.837952         0.777778      0.979275
# 1       SVM with rbf   0.825217         0.775424      0.948187
# 2  SVM using sigmoid   0.768659         0.757143      0.823834
#
#    Accuracy Score  Kappa Score  f1-score
# 0        0.843666     0.683363  0.866972
# 1        0.830189     0.656598  0.853147
# 2        0.770889     0.539319  0.789082

# %% [markdown]
# # Model 4(Support vector machine using kernel(Polynomial))

# %%
# build the model
svclassifier = SVC(kernel='poly')
# fit the model
svm_poly=svclassifier.fit(X_train, y_train)

# %%
# predict the values
y_pred  = svclassifier.predict(X_test)

# %%
plot_confusion_matrix(svm_poly)

# %%
test_report=get_test_report(svm_poly)
print(test_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.74      0.78       178
#            1       0.78      0.85      0.81       193
#
#     accuracy                           0.80       371
#    macro avg       0.80      0.80      0.80       371
# weighted avg       0.80      0.80      0.80       371

# %%
# compute kappa score on test set
kappa_value = kappa_score(svm_poly)

# print the kappa value
print(kappa_value)
# Out:
# 0.5935167195009714

# %%
plot_roc(svm_poly)

# %%
update_score_card(model_name='SVM with kernel(polynomial)')
# Out:
#                          Model  AUC Score  Precision Score  Recall Score  \
# 0                          SVM   0.837952         0.777778      0.979275
# 1                 SVM with rbf   0.825217         0.775424      0.948187
# 2            SVM using sigmoid   0.768659         0.757143      0.823834
# 3  SVM with kernel(polynomial)   0.795657         0.780952      0.849741
#
#    Accuracy Score  Kappa Score  f1-score
# 0        0.843666     0.683363  0.866972
# 1        0.830189     0.656598  0.853147
# 2        0.770889     0.539319  0.789082
# 3        0.797844     0.593517  0.813896

# %% [markdown]
# # Model 5(Support vector machine using kernel and degree=2)

# %%
# build the model
svclassifier_Poly = SVC(kernel='poly', degree = 2, gamma = 'auto')
# fit the model
svm=svclassifier_Poly.fit(X_train, y_train)

# %%
# predict the values
y_pred  = svclassifier_Poly.predict(X_test)

# %%
plot_confusion_matrix(svm)

# %%
test_report=get_test_report(svm)
print(test_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.76      0.82       178
#            1       0.80      0.91      0.85       193
#
#     accuracy                           0.84       371
#    macro avg       0.84      0.83      0.83       371
# weighted avg       0.84      0.84      0.83       371

# %%
# compute kappa score on test set
kappa_value = kappa_score(svm)

# print the kappa value
print(kappa_value)
# Out:
# 0.6688130186000907

# %%
plot_roc(svm)

# %%
update_score_card(model_name='SVM with kernel(ploynomial) with degree 2')
# Out:
#                                        Model  AUC Score  Precision Score  \
# 0                                        SVM   0.837952         0.777778
# 1                               SVM with rbf   0.825217         0.775424
# 2                          SVM using sigmoid   0.768659         0.757143
# 3                SVM with kernel(polynomial)   0.795657         0.780952
# 4  SVM with kernel(ploynomial) with degree 2   0.832581         0.802752
#
#    Recall Score  Accuracy Score  Kappa Score  f1-score
# 0      0.979275        0.843666     0.683363  0.866972
# 1      0.948187        0.830189     0.656598  0.853147
# 2      0.823834        0.770889     0.539319  0.789082
# 3      0.849741        0.797844     0.593517  0.813896
# 4      0.906736        0.835580     0.668813  0.851582

# %% [markdown]
# #  Model 6(Support vector machine using grid search)

# %%
# degree: Degree of the polynomial
# C: value of C parameter or regularisation parameter
# gamma:
param_grid = { 
    'degree': [2,4,6,8,10], 
    'gamma' : ['auto','scale' ],
    'C': [0.5, 1,1.5]
}

# %%
CV_rfc = GridSearchCV(estimator= svclassifier_Poly, param_grid=param_grid, scoring='accuracy', cv= 5)
# fit the model
CV_rfc.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVC(degree=2, gamma='auto', kernel='poly'),
#              param_grid={'C': [0.5, 1, 1.5], 'degree': [2, 4, 6, 8, 10],
#                          'gamma': ['auto', 'scale']},
#              scoring='accuracy')

# %%
# find the best parameters
CV_rfc.best_params_
# Out:
# {'C': 0.5, 'degree': 2, 'gamma': 'scale'}

# %%
# build the model with best parameters obtained from above code
svclassifier_Poly_Grid = SVC(kernel='poly', 
                            degree = 2, 
                            gamma = 'scale',
                           C = 1 )
# fit the model
svm=svclassifier_Poly_Grid.fit(X_train, y_train)

# %%
# predict the values
y_pred= svclassifier_Poly_Grid.predict(X_test)

# %%
plot_confusion_matrix(svm)

# %%
test_report=get_test_report(svm)
print(test_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.74      0.82       178
#            1       0.79      0.94      0.86       193
#
#     accuracy                           0.84       371
#    macro avg       0.85      0.84      0.84       371
# weighted avg       0.85      0.84      0.84       371

# %%
# compute kappa score on test set
kappa_value = kappa_score(svm)

# print the kappa value
print(kappa_value)
# Out:
# 0.678966897907103

# %%
plot_roc(svm)

# %%
update_score_card(model_name='SVM with grid search CV ')
# Out:
#                                        Model  AUC Score  Precision Score  \
# 0                                        SVM   0.837952         0.777778
# 1                               SVM with rbf   0.825217         0.775424
# 2                          SVM using sigmoid   0.768659         0.757143
# 3                SVM with kernel(polynomial)   0.795657         0.780952
# 4  SVM with kernel(ploynomial) with degree 2   0.832581         0.802752
# 5                   SVM with grid search CV    0.836889         0.793860
#
#    Recall Score  Accuracy Score  Kappa Score  f1-score
# 0      0.979275        0.843666     0.683363  0.866972
# 1      0.948187        0.830189     0.656598  0.853147
# 2      0.823834        0.770889     0.539319  0.789082
# 3      0.849741        0.797844     0.593517  0.813896
# 4      0.906736        0.835580     0.668813  0.851582
# 5      0.937824        0.840970     0.678967  0.859857

# %% [markdown]
# # Model 7(Decision Tree)

# %%
# instantiate the 'DecisionTreeClassifier' object using 'entropy' criterion
decision_tree = DecisionTreeClassifier(criterion = 'entropy', random_state = 10)

# fit the model using fit() on train data
decision_tree_model = decision_tree.fit(X_train, y_train)

# %%
labels=X_train.columns

#plot the decisin tree
fig=plt.figure(figsize=(30,30))
z=tree.plot_tree(decision_tree_model,
                feature_names=labels,
                class_names=['0','1'],
                filled=True)

# %%
y_pred=decision_tree_model.predict(X_test)

# %%
plot_confusion_matrix(decision_tree_model)

# %%
kappa_score(decision_tree_model)
# Out:
# 0.5133929872628173

# %%
test_report=get_test_report(decision_tree_model)
print(test_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.73      0.74       178
#            1       0.76      0.78      0.77       193
#
#     accuracy                           0.76       371
#    macro avg       0.76      0.76      0.76       371
# weighted avg       0.76      0.76      0.76       371

# %%
plot_roc(decision_tree)

# %%
update_score_card(model_name='Decision Tree')
# Out:
#                                        Model  AUC Score  Precision Score  \
# 0                                        SVM   0.837952         0.777778
# 1                               SVM with rbf   0.825217         0.775424
# 2                          SVM using sigmoid   0.768659         0.757143
# 3                SVM with kernel(polynomial)   0.795657         0.780952
# 4  SVM with kernel(ploynomial) with degree 2   0.832581         0.802752
# 5                   SVM with grid search CV    0.836889         0.793860
# 6                              Decision Tree   0.756360         0.758794
#
#    Recall Score  Accuracy Score  Kappa Score  f1-score
# 0      0.979275        0.843666     0.683363  0.866972
# 1      0.948187        0.830189     0.656598  0.853147
# 2      0.823834        0.770889     0.539319  0.789082
# 3      0.849741        0.797844     0.593517  0.813896
# 4      0.906736        0.835580     0.668813  0.851582
# 5      0.937824        0.840970     0.678967  0.859857
# 6      0.782383        0.757412     0.513393  0.770408

# %% [markdown]
# # Model 8(Decision Tree using pruning)

# %%
prune=DecisionTreeClassifier(max_depth=5,max_leaf_nodes=25,random_state=10)
decision_tree_prune=prune.fit(X_train,y_train)

# %%
labels=X_train.columns
fig=plt.figure(figsize=(30,30))
z=tree.plot_tree(decision_tree_prune,
                feature_names=labels,
                class_names=['0','1'],
                filled=True)

# %%
y_pred=decision_tree_prune.predict(X_test)

# %%
plot_confusion_matrix(decision_tree_prune)

# %%
test_report=get_test_report(decision_tree_prune)
print(test_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.70      0.78       178
#            1       0.77      0.93      0.84       193
#
#     accuracy                           0.82       371
#    macro avg       0.83      0.81      0.81       371
# weighted avg       0.83      0.82      0.81       371

# %%
plot_roc(decision_tree_prune)

# %%
update_score_card(model_name='Decision Tree Pruned')
# Out:
#                                        Model  AUC Score  Precision Score  \
# 0                                        SVM   0.837952         0.777778
# 1                               SVM with rbf   0.825217         0.775424
# 2                          SVM using sigmoid   0.768659         0.757143
# 3                SVM with kernel(polynomial)   0.795657         0.780952
# 4  SVM with kernel(ploynomial) with degree 2   0.832581         0.802752
# 5                   SVM with grid search CV    0.836889         0.793860
# 6                              Decision Tree   0.756360         0.758794
# 7                       Decision Tree Pruned   0.812045         0.768240
#
#    Recall Score  Accuracy Score  Kappa Score  f1-score
# 0      0.979275        0.843666     0.683363  0.866972
# 1      0.948187        0.830189     0.656598  0.853147
# 2      0.823834        0.770889     0.539319  0.789082
# 3      0.849741        0.797844     0.593517  0.813896
# 4      0.906736        0.835580     0.668813  0.851582
# 5      0.937824        0.840970     0.678967  0.859857
# 6      0.782383        0.757412     0.513393  0.770408
# 7      0.927461        0.816712     0.629588  0.840376

# %% [markdown]
# # Model 9(Decision Tree using grid search)

# %%
tuned_parameters=[{'criterion':['gini','entropy'],
                  'min_samples_split':[10,20,30],
                  'max_depth':[3,5,7],
                  'min_samples_leaf':[15,20,25,30,35],
                  'max_leaf_nodes':[5,10,15,20,25]
                  }]

# %%
tree_classification=DecisionTreeClassifier(random_state=10)
grid=GridSearchCV(estimator=tree_classification,
                 param_grid=tuned_parameters,
                 cv=10)
dt_grid=grid.fit(X_train,y_train)

print("best parameters:",dt_grid.best_params_,'\n')
# Out:
# best parameters: {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_leaf': 35, 'min_samples_split': 10}

# %%
dt_grid_model=DecisionTreeClassifier(criterion=dt_grid.best_params_.get('criterion'),
                                     max_depth=dt_grid.best_params_.get("max_depth"),
                                     max_leaf_nodes=dt_grid.best_params_.get("max_leaf_nodes"),
                                     min_samples_leaf=dt_grid.best_params_.get("max_leaf_nodes"),
                                     min_samples_split=dt_grid.best_params_.get("min_samples_split"),
                                     random_state=10)
dt_grid_model=dt_grid_model.fit(X_train,y_train)

# %%
# save the column names in 'labels'
lables = X_train.columns

# plot the decision tree 
fig = plt.figure(figsize=(30,30))
_ = tree.plot_tree(dt_grid_model, 
                   feature_names=lables,  
                   class_names=["0","1"],
                   filled=True)

# %%
y_pred=dt_grid_model.predict(X_test)

# %%
plot_confusion_matrix(dt_grid_model)

# %%
test_report=get_test_report(dt_grid_model)
print(test_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.69      0.78       178
#            1       0.77      0.93      0.84       193
#
#     accuracy                           0.82       371
#    macro avg       0.84      0.81      0.81       371
# weighted avg       0.83      0.82      0.81       371

# %%
plot_roc(dt_grid_model)

# %%
update_score_card(model_name='Decision Tree using grid search')
# Out:
#                                        Model  AUC Score  Precision Score  \
# 0                                        SVM   0.837952         0.777778
# 1                               SVM with rbf   0.825217         0.775424
# 2                          SVM using sigmoid   0.768659         0.757143
# 3                SVM with kernel(polynomial)   0.795657         0.780952
# 4  SVM with kernel(ploynomial) with degree 2   0.832581         0.802752
# 5                   SVM with grid search CV    0.836889         0.793860
# 6                              Decision Tree   0.756360         0.758794
# 7                       Decision Tree Pruned   0.812045         0.768240
# 8            Decision Tree using grid search   0.811827         0.765957
#
#    Recall Score  Accuracy Score  Kappa Score  f1-score
# 0      0.979275        0.843666     0.683363  0.866972
# 1      0.948187        0.830189     0.656598  0.853147
# 2      0.823834        0.770889     0.539319  0.789082
# 3      0.849741        0.797844     0.593517  0.813896
# 4      0.906736        0.835580     0.668813  0.851582
# 5      0.937824        0.840970     0.678967  0.859857
# 6      0.782383        0.757412     0.513393  0.770408
# 7      0.927461        0.816712     0.629588  0.840376
# 8      0.932642        0.816712     0.629425  0.841121

# %% [markdown]
# # Model 10(Ensemble Model)

# %%
# Create a random forest classifier
clf = RandomForestClassifier(n_estimators=10000, random_state=0, n_jobs=-1)

# Train the classifier
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=10000, n_jobs=-1, random_state=0)

# %%
feat_labels = X.columns.values
# Print the name and gini importance of each feature
feature_importance = []
for feature in zip(feat_labels, clf.feature_importances_):
    #rint(feature)
    feature_importance.append(feature)

# %%
feature_importance
# Out:
# [('Gender_M', 0.024986288978544338),
#  ('Gender_T', 0.0029594665380458037),
#  ('self_employed_Yes', 0.013724320563738169),
#  ('family_history_Yes', 0.07489036509186679),
#  ('work_interfere_Not mentioned', 0.13055989994913775),
#  ('work_interfere_Often', 0.047918702095712466),
#  ('work_interfere_Rarely', 0.029761859640728746),
#  ('work_interfere_Sometimes', 0.10045967954109389),
#  ('no_employees_100-500', 0.013865529798190489),
#  ('no_employees_26-100', 0.016672696764421516),
#  ('no_employees_500-1000', 0.006432108594292634),
#  ('no_employees_6-25', 0.016679444836900315),
#  ('no_employees_More than 1000', 0.013164425941100849),
#  ('remote_work_Yes', 0.02214673946356315),
#  ('tech_company_Yes', 0.0162087350905369),
#  ('benefits_No', 0.018963239404529878),
#  ('benefits_Yes', 0.023867179681881553),
#  ('care_options_Not sure', 0.01827904569803496),
#  ('care_options_Yes', 0.03489944173881338),
#  ('wellness_program_No', 0.01415307793359887),
#  ('wellness_program_Yes', 0.011516759921716333),
#  ('seek_help_No', 0.01769755139805428),
#  ('seek_help_Yes', 0.011965438547202292),
#  ('anonymity_No', 0.007915100156846641),
#  ('anonymity_Yes', 0.01872753361354547),
#  ('leave_Somewhat difficult', 0.012865888465091612),
#  ('leave_Somewhat easy', 0.01813708114415135),
#  ('leave_Very difficult', 0.012811749946318104),
#  ('leave_Very easy', 0.012067834049838409),
#  ('mental_health_consequence_No', 0.017508899692216615),
#  ('mental_health_consequence_Yes', 0.01615451746906891),
#  ('phys_health_consequence_No', 0.016148540109743245),
#  ('phys_health_consequence_Yes', 0.006570119169894995),
#  ('coworkers_Some of them', 0.022288470097550677),
#  ('coworkers_Yes', 0.015086377605841961),
#  ('supervisor_Some of them', 0.018778962700991043),
#  ('supervisor_Yes', 0.019273861367583873),
#  ('mental_health_interview_No', 0.01430437617845307),
#  ('mental_health_interview_Yes', 0.003804103028512416),
#  ('phys_health_interview_No', 0.022117287162817145),
#  ('phys_health_interview_Yes', 0.012702572837971103),
#  ('mental_vs_physical_No', 0.01826737409178716),
#  ('mental_vs_physical_Yes', 0.015335695619096895),
#  ('obs_consequence_Yes', 0.01736165828097427)]

# %%
# features that have an importance of more than 0.01
sfm = SelectFromModel(clf, threshold=0.01)

# %%
# Train the selector
sfm.fit(X_train, y_train)
# Out:
# SelectFromModel(estimator=RandomForestClassifier(n_estimators=10000, n_jobs=-1,
#                                                  random_state=0),
#                 threshold=0.01)

# %%
selected_features = []
# Print the names of the most important features
for feature_list_index in sfm.get_support(indices=True):
    selected_features.append(feat_labels[feature_list_index])

# %%
selected_features
# Out:
# ['Gender_M',
#  'self_employed_Yes',
#  'family_history_Yes',
#  'work_interfere_Not mentioned',
#  'work_interfere_Often',
#  'work_interfere_Rarely',
#  'work_interfere_Sometimes',
#  'no_employees_100-500',
#  'no_employees_26-100',
#  'no_employees_6-25',
#  'no_employees_More than 1000',
#  'remote_work_Yes',
#  'tech_company_Yes',
#  'benefits_No',
#  'benefits_Yes',
#  'care_options_Not sure',
#  'care_options_Yes',
#  'wellness_program_No',
#  'wellness_program_Yes',
#  'seek_help_No',
#  'seek_help_Yes',
#  'anonymity_Yes',
#  'leave_Somewhat difficult',
#  'leave_Somewhat easy',
#  'leave_Very difficult',
#  'leave_Very easy',
#  'mental_health_consequence_No',
#  'mental_health_consequence_Yes',
#  'phys_health_consequence_No',
#  'coworkers_Some of them',
#  'coworkers_Yes',
#  'supervisor_Some of them',
#  'supervisor_Yes',
#  'mental_health_interview_No',
#  'phys_health_interview_No',
#  'phys_health_interview_Yes',
#  'mental_vs_physical_No',
#  'mental_vs_physical_Yes',
#  'obs_consequence_Yes']

# %%
data_selected = df_dummy[selected_features]
data_selected.head()
# Out:
#     Gender_M  self_employed_Yes  family_history_Yes  \
# 18         1                  1                   1
# 19         1                  1                   1
# 20         1                  0                   1
# 21         1                  1                   0
# 22         1                  0                   0
#
#     work_interfere_Not mentioned  work_interfere_Often  work_interfere_Rarely  \
# 18                             0                     0                      0
# 19                             1                     0                      0
# 20                             0                     0                      0
# 21                             0                     0                      0
# 22                             0                     1                      0
#
#     work_interfere_Sometimes  no_employees_100-500  no_employees_26-100  \
# 18                         1                     0                    0
# 19                         0                     0                    0
# 20                         1                     1                    0
# 21                         0                     0                    0
# 22                         0                     0                    1
#
#     no_employees_6-25  no_employees_More than 1000  remote_work_Yes  \
# 18                  0                            0                1
# 19                  1                            0                1
# 20                  0                            0                0
# 21                  0                            0                1
# 22                  0                            0                1
#
#     tech_company_Yes  benefits_No  benefits_Yes  care_options_Not sure  \
# 18                 1            0             1                      1
# 19                 1            1             0                      0
# 20                 1            0             1                      0
# 21                 1            1             0                      0
# 22                 1            0             1                      0
#
#     care_options_Yes  wellness_program_No  wellness_program_Yes  seek_help_No  \
# 18                 0                    0                     1             0
# 19                 0                    0                     1             1
# 20                 1                    1                     0             1
# 21                 0                    1                     0             1
# 22                 1                    1                     0             1
#
#     seek_help_Yes  anonymity_Yes  leave_Somewhat difficult  \
# 18              0              1                         0
# 19              0              1                         0
# 20              0              0                         1
# 21              0              1                         1
# 22              0              0                         0
#
#     leave_Somewhat easy  leave_Very difficult  leave_Very easy  \
# 18                    0                     0                1
# 19                    1                     0                0
# 20                    0                     0                0
# 21                    0                     0                0
# 22                    0                     0                0
#
#     mental_health_consequence_No  mental_health_consequence_Yes  \
# 18                             1                              0
# 19                             1                              0
# 20                             0                              0
# 21                             1                              0
# 22                             0                              0
#
#     phys_health_consequence_No  coworkers_Some of them  coworkers_Yes  \
# 18                           1                       0              1
# 19                           1                       1              0
# 20                           1                       1              0
# 21                           1                       1              0
# 22                           1                       1              0
#
#     supervisor_Some of them  supervisor_Yes  mental_health_interview_No  \
# 18                        0               1                           1
# 19                        1               0                           0
# 20                        1               0                           1
# 21                        1               0                           1
# 22                        0               1                           1
#
#     phys_health_interview_No  phys_health_interview_Yes  \
# 18                         0                          1
# 19                         0                          0
# 20                         1                          0
# 21                         0                          0
# 22                         0                          0
#
#     mental_vs_physical_No  mental_vs_physical_Yes  obs_consequence_Yes
# 18                      0                       1                    1
# 19                      0                       0                    0
# 20                      1                       0                    0
# 21                      0                       1                    0
# 22                      1                       0                    0

# %%
data_standardised = pd.get_dummies(data_selected,drop_first=True)

# %%
# let us now split the dataset into train & test
X = data_standardised
y = df['treatment']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30, random_state=10)

# print the shape of 'x_train'
print("X_train ",X_train.shape)

# print the shape of 'x_test'
print("X_test ",X_test.shape)

# print the shape of 'y_train'
print("y_train ",y_train.shape)

# print the shape of 'y_test'
print("y_test ",y_test.shape)
# Out:
# X_train  (864, 39)
# X_test  (371, 39)
# y_train  (864,)
# y_test  (371,)

# %%
# build the model
gnb = GaussianNB()

# define the ovr strategy
GNB = OneVsRestClassifier(gnb)

# fit the model
GNB.fit(X_train, y_train)
# Out:
# OneVsRestClassifier(estimator=GaussianNB())

# %%
# predict the values
y_pred= GNB.predict(X_test)

# %%
result = classification_report(y_test,y_pred)

# print the result
print(result)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.67      0.77       178
#            1       0.75      0.93      0.83       193
#
#     accuracy                           0.81       371
#    macro avg       0.83      0.80      0.80       371
# weighted avg       0.82      0.81      0.80       371

# %%
# compute kappa score on test set
kappa_value = kappa_score(GNB)

# print the kappa value
print(kappa_value)
# Out:
# 0.6072804257696491

# %%
plot_roc(GNB)

# %%
update_score_card(model_name = 'Random Forest')
# Out:
#                                        Model  AUC Score  Precision Score  \
# 0                                        SVM   0.837952         0.777778
# 1                               SVM with rbf   0.825217         0.775424
# 2                          SVM using sigmoid   0.768659         0.757143
# 3                SVM with kernel(polynomial)   0.795657         0.780952
# 4  SVM with kernel(ploynomial) with degree 2   0.832581         0.802752
# 5                   SVM with grid search CV    0.836889         0.793860
# 6                              Decision Tree   0.756360         0.758794
# 7                       Decision Tree Pruned   0.812045         0.768240
# 8            Decision Tree using grid search   0.811827         0.765957
# 9                              Random Forest   0.800591         0.753138
#
#    Recall Score  Accuracy Score  Kappa Score  f1-score
# 0      0.979275        0.843666     0.683363  0.866972
# 1      0.948187        0.830189     0.656598  0.853147
# 2      0.823834        0.770889     0.539319  0.789082
# 3      0.849741        0.797844     0.593517  0.813896
# 4      0.906736        0.835580     0.668813  0.851582
# 5      0.937824        0.840970     0.678967  0.859857
# 6      0.782383        0.757412     0.513393  0.770408
# 7      0.927461        0.816712     0.629588  0.840376
# 8      0.932642        0.816712     0.629425  0.841121
# 9      0.932642        0.805930     0.607280  0.833333

# %% [markdown]
# # Model 11(Logistics regression using SGD)

# %%
X=df_dummy
y=pd.DataFrame(df_target)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30, random_state = 10)

# check the dimensions of the train & test subset using 'shape'
# print dimension of train set
print("X_train",X_train.shape)
print("y_train",y_train.shape)

# print dimension of test set
print("X_test",X_test.shape)
print("y_test",y_test.shape)
# Out:
# X_train (864, 44)
# y_train (864, 1)
# X_test (371, 44)
# y_test (371, 1)

# %%
# instantiate the 'SGDClassifier' to build model using SGD
# to perform logistic regression, consider the log-loss function 
# set 'random_state' to generate the same dataset each time you run the code 
SGD = SGDClassifier(loss = 'log', random_state = 10)

# fit the model on scaled training data
logreg_with_SGD = SGD.fit(X_train, y_train)

# %%
# use predict() to predict the class labels of target variable
y_pred = logreg_with_SGD.predict(X_test)

# %%
# call the function to plot the confusion matrix
# pass the logistic regression (SGD) model to the function
plot_confusion_matrix(logreg_with_SGD)

# %%
test_report = get_test_report(logreg_with_SGD)

# print the performace measures
print(test_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.78      0.81       178
#            1       0.81      0.87      0.84       193
#
#     accuracy                           0.82       371
#    macro avg       0.83      0.82      0.82       371
# weighted avg       0.83      0.82      0.82       371

# %%
kappa_value = kappa_score(logreg_with_SGD)

# print the kappa value
print(kappa_value)
# Out:
# 0.6478688141582583

# %%
plot_roc(logreg_with_SGD)

# %%
update_score_card(model_name = 'Logistic Regression (SGD)')
# Out:
#                                         Model  AUC Score  Precision Score  \
# 0                                         SVM   0.837952         0.777778
# 1                                SVM with rbf   0.825217         0.775424
# 2                           SVM using sigmoid   0.768659         0.757143
# 3                 SVM with kernel(polynomial)   0.795657         0.780952
# 4   SVM with kernel(ploynomial) with degree 2   0.832581         0.802752
# 5                    SVM with grid search CV    0.836889         0.793860
# 6                               Decision Tree   0.756360         0.758794
# 7                        Decision Tree Pruned   0.812045         0.768240
# 8             Decision Tree using grid search   0.811827         0.765957
# 9                               Random Forest   0.800591         0.753138
# 10                  Logistic Regression (SGD)   0.822874         0.807692
#
#     Recall Score  Accuracy Score  Kappa Score  f1-score
# 0       0.979275        0.843666     0.683363  0.866972
# 1       0.948187        0.830189     0.656598  0.853147
# 2       0.823834        0.770889     0.539319  0.789082
# 3       0.849741        0.797844     0.593517  0.813896
# 4       0.906736        0.835580     0.668813  0.851582
# 5       0.937824        0.840970     0.678967  0.859857
# 6       0.782383        0.757412     0.513393  0.770408
# 7       0.927461        0.816712     0.629588  0.840376
# 8       0.932642        0.816712     0.629425  0.841121
# 9       0.932642        0.805930     0.607280  0.833333
# 10      0.870466        0.824798     0.647869  0.837905

# %% [markdown]
# # Model 12(K Nearest Neighbours)

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier=KNeighborsClassifier(n_neighbors=5)
KNN=classifier.fit(X_train,y_train)

# %%
y_pred=classifier.predict(X_test)

# %%
plot_confusion_matrix(KNN)

# %%
kappa_score(KNN)
# Out:
# 0.5317627261253681

# %%
test_report=get_test_report(decision_tree_model)
print(test_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.80      0.77       178
#            1       0.80      0.74      0.77       193
#
#     accuracy                           0.77       371
#    macro avg       0.77      0.77      0.77       371
# weighted avg       0.77      0.77      0.77       371

# %%
plot_roc(decision_tree)

# %%
update_score_card(model_name='K Nearest Neighbours')
# Out:
#                                         Model  AUC Score  Precision Score  \
# 0                                         SVM   0.837952         0.777778
# 1                                SVM with rbf   0.825217         0.775424
# 2                           SVM using sigmoid   0.768659         0.757143
# 3                 SVM with kernel(polynomial)   0.795657         0.780952
# 4   SVM with kernel(ploynomial) with degree 2   0.832581         0.802752
# 5                    SVM with grid search CV    0.836889         0.793860
# 6                               Decision Tree   0.756360         0.758794
# 7                        Decision Tree Pruned   0.812045         0.768240
# 8             Decision Tree using grid search   0.811827         0.765957
# 9                               Random Forest   0.800591         0.753138
# 10                  Logistic Regression (SGD)   0.822874         0.807692
# 11                       K Nearest Neighbours   0.766752         0.797753
#
#     Recall Score  Accuracy Score  Kappa Score  f1-score
# 0       0.979275        0.843666     0.683363  0.866972
# 1       0.948187        0.830189     0.656598  0.853147
# 2       0.823834        0.770889     0.539319  0.789082
# 3       0.849741        0.797844     0.593517  0.813896
# 4       0.906736        0.835580     0.668813  0.851582
# 5       0.937824        0.840970     0.678967  0.859857
# 6       0.782383        0.757412     0.513393  0.770408
# 7       0.927461        0.816712     0.629588  0.840376
# 8       0.932642        0.816712     0.629425  0.841121
# 9       0.932642        0.805930     0.607280  0.833333
# 10      0.870466        0.824798     0.647869  0.837905
# 11      0.735751        0.765499     0.531763  0.765499

# %%
models_table=pd.read_clipboard()
models_table
# Out:
#                                         Model  AUC Score  Precision Score  \
# 0                                         SVM   0.837952         0.777778
# 1                                SVM with rbf   0.825217         0.775424
# 2                           SVM using sigmoid   0.768659         0.757143
# 3                 SVM with kernel(polynomial)   0.795657         0.780952
# 4   SVM with kernel(ploynomial) with degree 2   0.832581         0.802752
# 5                     SVM with grid search CV   0.836889         0.793860
# 6                               Decision Tree   0.756360         0.758794
# 7                        Decision Tree Pruned   0.812045         0.768240
# 8             Decision Tree using grid search   0.811827         0.765957
# 9                               Random Forest   0.800591         0.753138
# 10                  Logistic Regression (SGD)   0.822874         0.807692
# 11                       K Nearest Neighbours   0.766752         0.797753
#
#     Recall Score  Accuracy Score  Kappa Score  f1-score
# 0       0.979275        0.843666     0.683363  0.866972
# 1       0.948187        0.830189     0.656598  0.853147
# 2       0.823834        0.770889     0.539319  0.789082
# 3       0.849741        0.797844     0.593517  0.813896
# 4       0.906736        0.835580     0.668813  0.851582
# 5       0.937824        0.840970     0.678967  0.859857
# 6       0.782383        0.757412     0.513393  0.770408
# 7       0.927461        0.816712     0.629588  0.840376
# 8       0.932642        0.816712     0.629425  0.841121
# 9       0.932642        0.805930     0.607280  0.833333
# 10      0.870466        0.824798     0.647869  0.837905
# 11      0.735751        0.765499     0.531763  0.765499

# %%
plt.figure(figsize = (10,5))
ax = sns.barplot(x = models_table['Accuracy Score']*100, y =models_table['Model'], palette='Purples',)
plt.title("Plotting the Model Accuracy", fontsize=16, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Plotting the Model Accuracy')

# %% [markdown]
# # Conclusion:

# %% [markdown]
# Total 12 models have been built to predict whether an employee needs medical treatment or not.The best out of all these models are support vector machine which is the first model.We can see that the F1 score which is the harmonic mean between precision and recall is the highest in this model and the value is 0.886486.The accuracy of this model also stands above all other models with the value of 0.863636.
#
# We also consider the AUC score(area under the curve) to see which model is performing best among other models and for SVM model it is 0.852381 which is the highest among all the models.
#
# If we further see the kappa score which tells us about the agreement between the predicted and observed value, we can see that it is 0.719320 which shows that there is high agreement between predicted and observed values.
#
# If we see the confusion matrix then the type 1 error is less i.e.4 in other models type 1 error is more than 10.In this data set as we are predicting about the treatment of an employee,so type 1 error is important. As any employee having mental health issue and if we predict that employee as not having mental illness, can be fatal. So we see that the SVM model is the best model to predict which employee needs treatment.
#
# Hence,we will use the test data set on this model to predict whether an employee requires medical treatment or not.

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((864, 44), (371, 44), (864, 1), (371, 1))

# %%
from sklearn.model_selection import GridSearchCV

# defining Parameter Range
param_grid={'C':[0.1,1,10,100,1000],'gamma':[1,0.1,0.01,0.001,0.0001],'kernel':['rbf']}

grid=GridSearchCV(SVC(),param_grid,refit=True,verbose=3)

# fitting the model for grid search
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.503 total time=   0.2s
# [CV 2/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.503 total time=   0.0s
# [CV 3/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.503 total time=   0.1s
# [CV 4/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.497 total time=   0.1s
# [CV 5/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.500 total time=   0.1s
# [CV 1/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.803 total time=   0.0s
# [CV 2/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.815 total time=   0.0s
# [CV 3/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.786 total time=   0.0s
# [CV 4/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.757 total time=   0.0s
# [CV 5/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.797 total time=   0.0s
# [CV 1/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.671 total time=   0.0s
# [CV 2/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.659 total time=   0.1s
# [CV 3/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.653 total time=   0.0s
# [CV 4/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.647 total time=   0.2s
# [CV 5/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.651 total time=   0.2s
# [CV 1/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.503 total time=   0.1s
# [CV 2/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.503 total time=   0.1s
# [CV 3/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.503 total time=   0.1s
# [CV 4/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.497 total time=   0.1s
# [CV 5/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.500 total time=   0.1s
# [CV 1/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.503 total time=   0.1s
# [CV 2/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.503 total time=   0.0s
# [CV 3/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.503 total time=   0.0s
# [CV 4/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.497 total time=   0.0s
# [CV 5/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.500 total time=   0.0s
# [CV 1/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.682 total time=   0.1s
# [CV 2/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.699 total time=   0.1s
# [CV 3/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.705 total time=   0.1s
# [CV 4/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.746 total time=   0.1s
# [CV 5/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.692 total time=   0.8s
# [CV 1/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.832 total time=   0.0s
# [CV 2/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.815 total time=   0.0s
# [CV 3/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.844 total time=   0.1s
# [CV 4/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.803 total time=   0.5s
# [CV 5/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.797 total time=   0.2s
# [CV 1/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.832 total time=   0.1s
# [CV 2/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.827 total time=   0.1s
# [CV 3/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.809 total time=   0.2s
# [CV 4/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.786 total time=   0.1s
# [CV 5/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.785 total time=   0.1s
# [CV 1/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.728 total time=   0.2s
# [CV 2/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.705 total time=   0.2s
# [CV 3/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.757 total time=   0.2s
# [CV 4/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.699 total time=   0.3s
# [CV 5/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.698 total time=   0.2s
# [CV 1/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.503 total time=   0.3s
# [CV 2/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.503 total time=   0.2s
# [CV 3/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.503 total time=   0.2s
# [CV 4/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.497 total time=   0.2s
# [CV 5/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.500 total time=   0.1s
# [CV 1/5] END .........C=10, gamma=1, kernel=rbf;, score=0.694 total time=   0.1s
# [CV 2/5] END .........C=10, gamma=1, kernel=rbf;, score=0.717 total time=   0.3s
# [CV 3/5] END .........C=10, gamma=1, kernel=rbf;, score=0.705 total time=   0.3s
# [CV 4/5] END .........C=10, gamma=1, kernel=rbf;, score=0.769 total time=   0.3s
# [CV 5/5] END .........C=10, gamma=1, kernel=rbf;, score=0.692 total time=   0.2s
# [CV 1/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.757 total time=   0.2s
# [CV 2/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.780 total time=   0.2s
# [CV 3/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.792 total time=   0.2s
# [CV 4/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.780 total time=   0.3s
# [CV 5/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.762 total time=   0.1s
# [CV 1/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.855 total time=   0.1s
# [CV 2/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.838 total time=   0.0s
# [CV 3/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.832 total time=   0.0s
# [CV 4/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.803 total time=   0.0s
# [CV 5/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.791 total time=   0.0s
# [CV 1/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.832 total time=   0.0s
# [CV 2/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.832 total time=   0.0s
# [CV 3/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.815 total time=   0.0s
# [CV 4/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.780 total time=   0.0s
# [CV 5/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.785 total time=   0.0s
# [CV 1/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.728 total time=   0.0s
# [CV 2/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.705 total time=   0.0s
# [CV 3/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.775 total time=   0.0s
# [CV 4/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.705 total time=   0.0s
# [CV 5/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.709 total time=   0.0s
# [CV 1/5] END ........C=100, gamma=1, kernel=rbf;, score=0.694 total time=   0.0s
# [CV 2/5] END ........C=100, gamma=1, kernel=rbf;, score=0.717 total time=   0.1s
# [CV 3/5] END ........C=100, gamma=1, kernel=rbf;, score=0.705 total time=   0.0s
# [CV 4/5] END ........C=100, gamma=1, kernel=rbf;, score=0.769 total time=   0.0s
# [CV 5/5] END ........C=100, gamma=1, kernel=rbf;, score=0.692 total time=   0.0s
# [CV 1/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.751 total time=   0.0s
# [CV 2/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.780 total time=   0.0s
# [CV 3/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.763 total time=   0.0s
# [CV 4/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.775 total time=   0.0s
# [CV 5/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.767 total time=   0.0s
# [CV 1/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.821 total time=   0.0s
# [CV 2/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.809 total time=   0.0s
# [CV 3/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.815 total time=   0.0s
# [CV 4/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.769 total time=   0.0s
# [CV 5/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.779 total time=   0.1s
# [CV 1/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.855 total time=   0.0s
# [CV 2/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.838 total time=   0.0s
# [CV 3/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.832 total time=   0.0s
# [CV 4/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.803 total time=   0.1s
# [CV 5/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.791 total time=   0.1s
# [CV 1/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.832 total time=   0.1s
# [CV 2/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.832 total time=   0.1s
# [CV 3/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.815 total time=   0.0s
# [CV 4/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.780 total time=   0.0s
# [CV 5/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.785 total time=   0.0s
# [CV 1/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.694 total time=   0.0s
# [CV 2/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.717 total time=   0.0s
# [CV 3/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.705 total time=   0.0s
# [CV 4/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.769 total time=   0.0s
# [CV 5/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.692 total time=   0.0s
# [CV 1/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.751 total time=   0.0s
# [CV 2/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.780 total time=   0.0s
# [CV 3/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.763 total time=   0.0s
# [CV 4/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.775 total time=   0.2s
# [CV 5/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.767 total time=   0.0s
# [CV 1/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.746 total time=   0.3s
# [CV 2/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.763 total time=   0.3s
# [CV 3/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.775 total time=   0.3s
# [CV 4/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.757 total time=   0.2s
# [CV 5/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.727 total time=   0.3s
# [CV 1/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.855 total time=   0.0s
# [CV 2/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.838 total time=   0.1s
# [CV 3/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.832 total time=   0.1s
# [CV 4/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.803 total time=   0.1s
# [CV 5/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.791 total time=   0.0s
# [CV 1/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.855 total time=   0.0s
# [CV 2/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.838 total time=   0.0s
# [CV 3/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.832 total time=   0.0s
# [CV 4/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.803 total time=   0.0s
# [CV 5/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.791 total time=   0.0s
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10, 100, 1000],
#                          'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#                          'kernel': ['rbf']},
#              verbose=3)

# %%
# print best parameter after tuning

print(grid.best_params_)

# print how our model looks after hyper-parameter tuning
print(grid.best_estimator_)
# Out:
# {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'}
# SVC(C=10, gamma=0.01)

# %%
y_test_pred=grid.predict(X_test)
print(classification_report(y_test,y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.70      0.81       178
#            1       0.78      0.98      0.87       193
#
#     accuracy                           0.84       371
#    macro avg       0.87      0.84      0.84       371
# weighted avg       0.87      0.84      0.84       371

# %%
# Now will perform RandomForest Classifier

param_grid = { 
    'n_estimators': [100, 200, 500],
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth' : [4,5,6,7,8],
    'criterion' :['gini', 'entropy']
}

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier()
CV_rfc = GridSearchCV(estimator=rfc, param_grid=param_grid, cv= 5)
CV_rfc.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [4, 5, 6, 7, 8],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [200, 500]})

# %%
CV_rfc.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 8,
#  'max_features': 'log2',
#  'n_estimators': 200}

# %%
model3=RandomForestClassifier(criterion='gini',max_depth=8,max_features='log2',n_estimators=200)
model3.fit(X_train,y_train)
y_pred=model3.predict(X_test)

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[127,  51],
#        [ 16, 177]], dtype=int64)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.71      0.79       178
#            1       0.78      0.92      0.84       193
#
#     accuracy                           0.82       371
#    macro avg       0.83      0.82      0.82       371
# weighted avg       0.83      0.82      0.82       371
